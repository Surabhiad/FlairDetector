# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Checking the number of posts in each flairs taken

# %%
import pandas as pd

# %%
posts = pd.read_csv('data.csv')

# %%
posts['flair'].value_counts()
# Out:
# Policy/Economy        200
# Business/Finance      200
# AskIndia              200
# Sports                200
# Politics              200
# Photography           200
# Scheduled             200
# Non-Political         200
# Science/Technology    200
# Food                    2
# [R]eddiquette           1
# Name: flair, dtype: int64

# %% [markdown]
# ### Importing Dependencies

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ### Function for creation of WordCloud

# %%
def plotwordcloud(XX,xx):
    comment_words = '' 
    stopwords = set(STOPWORDS) 

    # iterate through the csv file 
    for val in XX: 
      
        # typecaste each val to string 
        val = str(val) 
  
        # split the value 
        tokens = val.split() 
      
        # Converts each token into lowercase 
        for i in range(len(tokens)): 
            tokens[i] = tokens[i].lower() 
      
        comment_words += " ".join(tokens)+" "
  
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
    # plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off")
    plt.tight_layout(pad = 0) 
    plt.title(xx,fontsize=32)
    plt.show()

# %% [markdown]
# ### Creating DataFrames for each Category

# %%
sports=posts.loc[posts['flair']=='Sports']
photography=posts.loc[posts['flair']=='Photography']
business=posts.loc[posts['flair']=='Business/Finance']
science=posts.loc[posts['flair']=='Science/Technology']
politics=posts.loc[posts['flair']=='Politics']
nonpolitical=posts.loc[posts['flair']=='Non-Political']
askindia=posts.loc[posts['flair']=='AskIndia']
scheduled=posts.loc[posts['flair']=='Scheduled']
policyeconomy=posts.loc[posts['flair']=='Policy/Economy']

# %%
plotwordcloud(sports['title'],"SPORTS")

# %%
plotwordcloud(photography['title'],"PHOTOGRAPHY")

# %%
plotwordcloud(business['title'],"Business/Finance")

# %%
plotwordcloud(science['title'],"Science/Technology")

# %%
plotwordcloud(politics['title'],"Politics")

# %%
plotwordcloud(nonpolitical['title'],"NON-POLITICAL")

# %%
plotwordcloud(askindia['title'],"ASKINDIA")
